# %%
import boto3
import pandas as pd
import os

directory=r'C:\Users\A4023862\OneDrive - Astellas Pharma Inc\INT Workforce Planning\data\jd_data'

s3 = boto3.resource('s3', aws_access_key_id='AKIAUHGSEVS4FA33QNOJ',
aws_secret_access_key='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')
bucketname = 'jobpostingsprocessed'

n=len(os.listdir(directory))
df = pd.DataFrame()

for x in range(1, 3):
    filename = 'df'+str(x)+'.csv'
    obj = s3.Object(bucketname, filename)
    body = obj.get()['Body']
    data = pd.read_csv(body)
    df=df.append(data)
    print(filename)
    print(data.shape)
# Out:
# df1.csv
# (50000, 7)
# df2.csv
# (50000, 7)

# %%
df.head()
# Out:
#   Unnamed: 0                    category  \
# 0      value                   Insurance
# 1      value              Administrative
# 2      value              Administrative
# 3      value  Construction-or-facilities
# 4      value        Computer-or-internet
#
#                                  company_description  \
# 0  Macy's, Inc., one of America’s most enduring, ...
# 1  In early 2019, CHI and Dignity Health united a...
# 2  Pediatric Therapy Agency in the West Valley! W...
# 3  At Kleinfelder, we have been connecting great ...
# 4  MUFG Union Bank, N.A. operates 355 branches, c...
#
#                                    company_name  \
# 0                                        Macy’s
# 1  CHI St. Luke's Health - The Woodlands Campus
# 2                          Wee Care Corporation
# 3                             Kleinfelder, Inc.
# 4                                          MUFG
#
#                                      job_description  \
# ...

# %%
df['category'].unique()
# Out:
# array(['Insurance', 'Administrative', 'Construction-or-facilities',
#        'Computer-or-internet', 'Retail', 'Manufacturing-or-mechanical',
#        'Law-Enforcement-or-security', 'Restaurant-or-food-Service',
#        'Healthcare', 'Engineering-or-architecture', 'Legal',
#        'Hospitality-or-travel', 'Human-Resources',
#        'Transportation-or-logistics', 'Accounting-or-finance',
#        'Non-profit/volunteering', 'Customer-Service',
#        'Marketing-or-advertising-or-pr', 'Banking-or-loans',
#        'Education-or-training', 'Sales', 'Upper-Management-or-consulting',
#        'Arts-or-entertainment-or-publishing', 'Telecommunications',
#        'Real-Estate', 'Government-or-military', 'Pharmaceutical/bio-tech',
#        'Restaurant/food Service', 'Transportation/logistics',
#        'Upper Management/consulting', 'Human Resources',
#        'Marketing/advertising/pr', 'Computer/internet',
#        'Customer Service', 'Manufacturing/mechanical',
# ...

# %%
df_biotech=df[df['category']=='Pharmaceutical/bio-tech', 'Healthcare']

# %%
df_biotech.groupby('company_name').count()['uniq_id'].reset_index(name='count').sort_values(['count'], ascending=False)
# Out:
#                        company_name  count
# 98                       CVS Health     15
# 299                         Labcorp      7
# 619                       WALGREENS      6
# 337  Memorial Hermann Health System      6
# 298                   Kroger Stores      5
# ..                              ...    ...
# 231                HNL Lab Medicine      1
# 232      Hackensack Meridian Health      1
# 233                          Haggen      1
# 234                       Hannaford      1
# 649                        vivitide      1
#
# [650 rows x 2 columns]

# %%
df.to_csv(r'C:\Users\A4023862\OneDrive - Astellas Pharma Inc\INT Workforce Planning\data\test.csv')
