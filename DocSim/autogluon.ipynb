# %%
import numpy as np
import warnings
import matplotlib.pyplot as plt

from autogluon.core.utils.loaders import load_pd

sts_train_data = load_pd.load('https://autogluon-text.s3-accelerate.amazonaws.com/glue/sts/train.parquet')[['sentence1', 'sentence2', 'score']]
sts_test_data = load_pd.load('https://autogluon-text.s3-accelerate.amazonaws.com/glue/sts/dev.parquet')[['sentence1', 'sentence2', 'score']]
sts_train_data.head(10)
# Out:
#                                        sentence1  \
# 0                         A plane is taking off.
# 1                A man is playing a large flute.
# 2  A man is spreading shreded cheese on a pizza.
# 3                   Three men are playing chess.
# 4                    A man is playing the cello.
# 5                         Some men are fighting.
# 6                              A man is smoking.
# 7                  The man is playing the piano.
# 8      A man is playing on a guitar and singing.
# 9  A person is throwing a cat on to the ceiling.
#
#                                            sentence2  score
# 0                        An air plane is taking off.   5.00
# 1                          A man is playing a flute.   3.80
# 2  A man is spreading shredded cheese on an uncoo...   3.80
# 3                         Two men are playing chess.   2.60
# 4                 A man seated is playing the cello.   4.25
# 5                              Two men are fighting.   4.25
# 6                                  A man is skating.   0.50
# 7                     The man is playing the guitar.   1.60
# 8  A woman is playing an acoustic guitar and sing...   2.20
# 9              A person throws a cat on the ceiling.   5.00

# %%
from autogluon.multimodal import MultiModalPredictor
import uuid
sts_model_path = f"./tmp/{uuid.uuid4().hex}-automm_sts"
predictor_sts = MultiModalPredictor(label='score', path=sts_model_path)
predictor_sts.fit(sts_train_data, time_limit=60)
# Out:
# Global seed set to 123
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\site-packages\urllib3\connectionpool.py:703 in    │
# │ urlopen                                                                                          │
# │                                                                                                  │
# │    700 │   │   │   │   self._prepare_proxy(conn)                                                 │
# │    701 │   │   │                                                                                 │
# │    702 │   │   │   # Make the request on the httplib connection object.                          │
# │ ❱  703 │   │   │   httplib_response = self._make_request(                                        │
# │    704 │   │   │   │   conn,                                                                     │
# │    705 │   │   │   │   method,                                                                   │
# │    706 │   │   │   │   url,                                                                      │
# │                                                                                                  │
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\site-packages\urllib3\connectionpool.py:386 in    │
# │ _make_request                                                                                    │
# │                                                                                                  │
# │    383 │   │                                                                                     │
# │    384 │   │   # Trigger any extra validation we need to do.                                     │
# │    385 │   │   try:                                                                              │
# │ ❱  386 │   │   │   self._validate_conn(conn)                                                     │
# │    387 │   │   except (SocketTimeout, BaseSSLError) as e:                                        │
# │    388 │   │   │   # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.         │
# │    389 │   │   │   self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)               │
# │                                                                                                  │
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\site-packages\urllib3\connectionpool.py:1042 in   │
# │ _validate_conn                                                                                   │
# │                                                                                                  │
# │   1039 │   │                                                                                     │
# │   1040 │   │   # Force connect early to allow us to validate the connection.                     │
# │   1041 │   │   if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`          │
# │ ❱ 1042 │   │   │   conn.connect()                                                                │
# │   1043 │   │                                                                                     │
# │   1044 │   │   if not conn.is_verified:                                                          │
# │   1045 │   │   │   warnings.warn(                                                                │
# │                                                                                                  │
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\site-packages\urllib3\connection.py:414 in        │
# │ connect                                                                                          │
# │                                                                                                  │
# │   411 │   │   ):                                                                                 │
# │   412 │   │   │   context.load_default_certs()                                                   │
# │   413 │   │                                                                                      │
# │ ❱ 414 │   │   self.sock = ssl_wrap_socket(                                                       │
# │   415 │   │   │   sock=conn,                                                                     │
# │   416 │   │   │   keyfile=self.key_file,                                                         │
# │   417 │   │   │   certfile=self.cert_file,                                                       │
# │                                                                                                  │
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\site-packages\urllib3\util\ssl_.py:449 in         │
# │ ssl_wrap_socket                                                                                  │
# │                                                                                                  │
# │   446 │   │   )                                                                                  │
# │   447 │                                                                                          │
# │   448 │   if send_sni:                                                                           │
# │ ❱ 449 │   │   ssl_sock = _ssl_wrap_socket_impl(                                                  │
# │   450 │   │   │   sock, context, tls_in_tls, server_hostname=server_hostname                     │
# │   451 │   │   )                                                                                  │
# │   452 │   else:                                                                                  │
# │                                                                                                  │
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\site-packages\urllib3\util\ssl_.py:493 in         │
# │ _ssl_wrap_socket_impl                                                                            │
# │                                                                                                  │
# │   490 │   │   return SSLTransport(sock, ssl_context, server_hostname)                            │
# │   491 │                                                                                          │
# │   492 │   if server_hostname:                                                                    │
# │ ❱ 493 │   │   return ssl_context.wrap_socket(sock, server_hostname=server_hostname)              │
# │   494 │   else:                                                                                  │
# │   495 │   │   return ssl_context.wrap_socket(sock)                                               │
# │   496                                                                                            │
# │                                                                                                  │
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\ssl.py:501 in wrap_socket                         │
# │                                                                                                  │
# │    498 │   │   │   │   │   server_hostname=None, session=None):                                  │
# │    499 │   │   # SSLSocket class handles server_hostname encoding before it calls                │
# │    500 │   │   # ctx._wrap_socket()                                                              │
# │ ❱  501 │   │   return self.sslsocket_class._create(                                              │
# │    502 │   │   │   sock=sock,                                                                    │
# │    503 │   │   │   server_side=server_side,                                                      │
# │    504 │   │   │   do_handshake_on_connect=do_handshake_on_connect,                              │
# │                                                                                                  │
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\ssl.py:1041 in _create                            │
# │                                                                                                  │
# │   1038 │   │   │   │   │   if timeout == 0.0:                                                    │
# │   1039 │   │   │   │   │   │   # non-blocking                                                    │
# │   1040 │   │   │   │   │   │   raise ValueError("do_handshake_on_connect should not be specifie  │
# │ ❱ 1041 │   │   │   │   │   self.do_handshake()                                                   │
# │   1042 │   │   │   except (OSError, ValueError):                                                 │
# │   1043 │   │   │   │   self.close()                                                              │
# │   1044 │   │   │   │   raise                                                                     │
# │                                                                                                  │
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\ssl.py:1310 in do_handshake                       │
# │                                                                                                  │
# │   1307 │   │   try:                                                                              │
# │   1308 │   │   │   if timeout == 0.0 and block:                                                  │
# │   1309 │   │   │   │   self.settimeout(None)                                                     │
# │ ❱ 1310 │   │   │   self._sslobj.do_handshake()                                                   │
# │   1311 │   │   finally:                                                                          │
# │   1312 │   │   │   self.settimeout(timeout)                                                      │
# │   1313                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer
# certificate (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\site-packages\requests\adapters.py:489 in send    │
# │                                                                                                  │
# │   486 │   │                                                                                      │
# │   487 │   │   try:                                                                               │
# │   488 │   │   │   if not chunked:                                                                │
# │ ❱ 489 │   │   │   │   resp = conn.urlopen(                                                       │
# │   490 │   │   │   │   │   method=request.method,                                                 │
# │   491 │   │   │   │   │   url=url,                                                               │
# │   492 │   │   │   │   │   body=request.body,                                                     │
# │                                                                                                  │
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\site-packages\urllib3\connectionpool.py:787 in    │
# │ urlopen                                                                                          │
# │                                                                                                  │
# │    784 │   │   │   elif isinstance(e, (SocketError, HTTPException)):                             │
# │    785 │   │   │   │   e = ProtocolError("Connection aborted.", e)                               │
# │    786 │   │   │                                                                                 │
# │ ❱  787 │   │   │   retries = retries.increment(                                                  │
# │    788 │   │   │   │   method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]           │
# │    789 │   │   │   )                                                                             │
# │    790 │   │   │   retries.sleep()                                                               │
# │                                                                                                  │
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\site-packages\urllib3\util\retry.py:592 in        │
# │ increment                                                                                        │
# │                                                                                                  │
# │   589 │   │   )                                                                                  │
# │   590 │   │                                                                                      │
# │   591 │   │   if new_retry.is_exhausted():                                                       │
# │ ❱ 592 │   │   │   raise MaxRetryError(_pool, url, error or ResponseError(cause))                 │
# │   593 │   │                                                                                      │
# │   594 │   │   log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)                  │
# │   595                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# MaxRetryError: HTTPSConnectionPool(host='cdn-lfs.huggingface.co', port=443): Max retries exceeded with url:
# /google/electra-base-discriminator/ff381b988006468d184eb8c1c090be15553155daa960587e8d86465969f1a0c1?response-conten
# t-disposition=attachment%3B%20filename%3D%22pytorch_model.bin%22&Expires=1669895041&Policy=eyJTdGF0ZW1lbnQiOlt7IlJl
# c291cmNlIjoiaHR0cHM6Ly9jZG4tbGZzLmh1Z2dpbmdmYWNlLmNvL2dvb2dsZS9lbGVjdHJhLWJhc2UtZGlzY3JpbWluYXRvci9mZjM4MWI5ODgwMDY
# 0NjhkMTg0ZWI4YzFjMDkwYmUxNTU1MzE1NWRhYTk2MDU4N2U4ZDg2NDY1OTY5ZjFhMGMxP3Jlc3BvbnNlLWNvbnRlbnQtZGlzcG9zaXRpb249YXR0YW
# NobWVudCUzQiUyMGZpbGVuYW1lJTNEJTIycHl0b3JjaF9tb2RlbC5iaW4lMjIiLCJDb25kaXRpb24iOnsiRGF0ZUxlc3NUaGFuIjp7IkFXUzpFcG9ja
# FRpbWUiOjE2Njk4OTUwNDF9fX1dfQ__&Signature=ptbGGwmN-2yd3SxxLvBmrQNy0cIguya2BytPOENZG177zvP-pRKK0NHldihzZ~Q50cRFh9EGp
# 0lGhG1QzfDjLf3mwa-zrlA5ua~H2CLAEuL5H-hZC5iQTFlMC8R~svVMQuKs0go81o2Ir~0p6Zno752s2e5WFi9OqH0ybJGxycbRU8L644ADm~GAA8Lh
# aFO6M4CTYKmxF~syOgRmsir457JNb7ToqPJ-12nmA2HdmPAsaT0DNX5h-J7yGcZOCYsFkYVSWNj5q2X2ptytO65ScbASLXt8UmSmHv1izjif3CtRKAQ
# 8h6oW2jaPg~6ckDT72f5p9qtYQCLrMjuaGvDWiA__&Key-Pair-Id=KVTP0A1DKRTAX (Caused by SSLError(SSLCertVerificationError(1,
# '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate
# (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ C:\Users\A4023862\AppData\Local\Temp\ipykernel_21452\2685820753.py:5 in <module>                 │
# │                                                                                                  │
# │ [Errno 2] No such file or directory:                                                             │
# │ 'C:\\Users\\A4023862\\AppData\\Local\\Temp\\ipykernel_21452\\2685820753.py'                      │
# │                                                                                                  │
# │ C:\Users\A4023862\AppData\Roaming\Python\Python39\site-packages\autogluon\multimodal\predictor.p │
# │ y:867 in fit                                                                                     │
# │                                                                                                  │
# │    864 │   │   │   )                                                                             │
# │    865 │   │   │   return predictor                                                              │
# │    866 │   │                                                                                     │
# │ ❱  867 │   │   self._fit(**_fit_args)                                                            │
# │    868 │   │   training_end = time.time()                                                        │
# │    869 │   │   self.elapsed_time = (training_end - training_start) / 60.0                        │
# │    870 │   │   logger.info(f"Models and intermediate outputs are saved to {self._save_path} ")   │
# │                                                                                                  │
# │ C:\Users\A4023862\AppData\Roaming\Python\Python39\site-packages\autogluon\multimodal\predictor.p │
# │ y:1176 in _fit                                                                                   │
# │                                                                                                  │
# │   1173 │   │   config = select_model(config=config, df_preprocessor=df_preprocessor)             │
# │   1174 │   │                                                                                     │
# │   1175 │   │   if self._model is None:                                                           │
# │ ❱ 1176 │   │   │   model = create_fusion_model(                                                  │
# │   1177 │   │   │   │   config=config,                                                            │
# │   1178 │   │   │   │   num_classes=self._output_shape,                                           │
# │   1179 │   │   │   │   classes=self._classes,                                                    │
# │                                                                                                  │
# │ C:\Users\A4023862\AppData\Roaming\Python\Python39\site-packages\autogluon\multimodal\utils\model │
# │ .py:391 in create_fusion_model                                                                   │
# │                                                                                                  │
# │   388 │                                                                                          │
# │   389 │   for model_name in names:                                                               │
# │   390 │   │   model_config = getattr(config.model, model_name)                                   │
# │ ❱ 391 │   │   model = create_model(                                                              │
# │   392 │   │   │   model_name=model_name,                                                         │
# │   393 │   │   │   model_config=model_config,                                                     │
# │   394 │   │   │   num_classes=num_classes,                                                       │
# │                                                                                                  │
# │ C:\Users\A4023862\AppData\Roaming\Python\Python39\site-packages\autogluon\multimodal\utils\model │
# │ .py:188 in create_model                                                                          │
# │                                                                                                  │
# │   185 │   │   │   pretrained=pretrained,                                                         │
# │   186 │   │   )                                                                                  │
# │   187 │   elif model_name.lower().startswith(HF_TEXT):                                           │
# │ ❱ 188 │   │   model = HFAutoModelForTextPrediction(                                              │
# │   189 │   │   │   prefix=model_name,                                                             │
# │   190 │   │   │   checkpoint_name=model_config.checkpoint_name,                                  │
# │   191 │   │   │   num_classes=num_classes,                                                       │
# │                                                                                                  │
# │ C:\Users\A4023862\AppData\Roaming\Python\Python39\site-packages\autogluon\multimodal\models\hugg │
# │ ingface_text.py:79 in __init__                                                                   │
# │                                                                                                  │
# │    76 │   │   self.checkpoint_name = checkpoint_name                                             │
# │    77 │   │   self.num_classes = num_classes                                                     │
# │    78 │   │                                                                                      │
# │ ❱  79 │   │   self.config, self.model = get_hf_config_and_model(                                 │
# │    80 │   │   │   checkpoint_name=checkpoint_name, pretrained=pretrained, low_cpu_mem_usage=lo   │
# │    81 │   │   )                                                                                  │
# │    82                                                                                            │
# │                                                                                                  │
# │ C:\Users\A4023862\AppData\Roaming\Python\Python39\site-packages\autogluon\multimodal\models\util │
# │ s.py:560 in get_hf_config_and_model                                                              │
# │                                                                                                  │
# │   557 │   config = AutoConfig.from_pretrained(checkpoint_name)                                   │
# │   558 │                                                                                          │
# │   559 │   if pretrained:                                                                         │
# │ ❱ 560 │   │   model = AutoModel.from_pretrained(checkpoint_name, low_cpu_mem_usage=low_cpu_mem   │
# │   561 │   else:                                                                                  │
# │   562 │   │   model = AutoModel.from_config(config)                                              │
# │   563                                                                                            │
# │                                                                                                  │
# │ C:\Users\A4023862\AppData\Roaming\Python\Python39\site-packages\transformers\models\auto\auto_fa │
# │ ctory.py:463 in from_pretrained                                                                  │
# │                                                                                                  │
# │   460 │   │   │   )                                                                              │
# │   461 │   │   elif type(config) in cls._model_mapping.keys():                                    │
# │   462 │   │   │   model_class = _get_model_class(config, cls._model_mapping)                     │
# │ ❱ 463 │   │   │   return model_class.from_pretrained(                                            │
# │   464 │   │   │   │   pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs,   │
# │   465 │   │   │   )                                                                              │
# │   466 │   │   raise ValueError(                                                                  │
# │                                                                                                  │
# │ C:\Users\A4023862\AppData\Roaming\Python\Python39\site-packages\transformers\modeling_utils.py:2 │
# │ 089 in from_pretrained                                                                           │
# │                                                                                                  │
# │   2086 │   │   │   │   │   │   _raise_exceptions_for_missing_entries=False,                      │
# │   2087 │   │   │   │   │   │   _commit_hash=commit_hash,                                         │
# │   2088 │   │   │   │   │   )                                                                     │
# │ ❱ 2089 │   │   │   │   │   resolved_archive_file = cached_file(pretrained_model_name_or_path, f  │
# │   2090 │   │   │   │   │                                                                         │
# │   2091 │   │   │   │   │   # Since we set _raise_exceptions_for_missing_entries=False, we don't  │
# │   2092 │   │   │   │   │   # result when internet is up, the repo and revision exist, but the f  │
# │                                                                                                  │
# │ C:\Users\A4023862\AppData\Roaming\Python\Python39\site-packages\transformers\utils\hub.py:409 in │
# │ cached_file                                                                                      │
# │                                                                                                  │
# │    406 │   user_agent = http_user_agent(user_agent)                                              │
# │    407 │   try:                                                                                  │
# │    408 │   │   # Load from URL or cache if already cached                                        │
# │ ❱  409 │   │   resolved_file = hf_hub_download(                                                  │
# │    410 │   │   │   path_or_repo_id,                                                              │
# │    411 │   │   │   filename,                                                                     │
# │    412 │   │   │   subfolder=None if len(subfolder) == 0 else subfolder,                         │
# │                                                                                                  │
# │ C:\Users\A4023862\AppData\Roaming\Python\Python39\site-packages\huggingface_hub\utils\_validator │
# │ s.py:124 in _inner_fn                                                                            │
# │                                                                                                  │
# │   121 │   │   │   │   fn_name=fn.__name__, has_token=has_token, kwargs=kwargs                    │
# │   122 │   │   │   )                                                                              │
# │   123 │   │                                                                                      │
# │ ❱ 124 │   │   return fn(*args, **kwargs)                                                         │
# │   125 │                                                                                          │
# │   126 │   return _inner_fn  # type: ignore                                                       │
# │   127                                                                                            │
# │                                                                                                  │
# │ C:\Users\A4023862\AppData\Roaming\Python\Python39\site-packages\huggingface_hub\file_download.py │
# │ :1242 in hf_hub_download                                                                         │
# │                                                                                                  │
# │   1239 │   │   with temp_file_manager() as temp_file:                                            │
# │   1240 │   │   │   logger.info("downloading %s to %s", url, temp_file.name)                      │
# │   1241 │   │   │                                                                                 │
# │ ❱ 1242 │   │   │   http_get(                                                                     │
# │   1243 │   │   │   │   url_to_download,                                                          │
# │   1244 │   │   │   │   temp_file,                                                                │
# │   1245 │   │   │   │   proxies=proxies,                                                          │
# │                                                                                                  │
# │ C:\Users\A4023862\AppData\Roaming\Python\Python39\site-packages\huggingface_hub\file_download.py │
# │ :475 in http_get                                                                                 │
# │                                                                                                  │
# │    472 │   headers = copy.deepcopy(headers) or {}                                                │
# │    473 │   if resume_size > 0:                                                                   │
# │    474 │   │   headers["Range"] = "bytes=%d-" % (resume_size,)                                   │
# │ ❱  475 │   r = _request_wrapper(                                                                 │
# │    476 │   │   method="GET",                                                                     │
# │    477 │   │   url=url,                                                                          │
# │    478 │   │   stream=True,                                                                      │
# │                                                                                                  │
# │ C:\Users\A4023862\AppData\Roaming\Python\Python39\site-packages\huggingface_hub\file_download.py │
# │ :438 in _request_wrapper                                                                         │
# │                                                                                                  │
# │    435 │   │   return response                                                                   │
# │    436 │                                                                                         │
# │    437 │   # 3. Exponential backoff                                                              │
# │ ❱  438 │   return http_backoff(                                                                  │
# │    439 │   │   method=method,                                                                    │
# │    440 │   │   url=url,                                                                          │
# │    441 │   │   max_retries=max_retries,                                                          │
# │                                                                                                  │
# │ C:\Users\A4023862\AppData\Roaming\Python\Python39\site-packages\huggingface_hub\utils\_http.py:1 │
# │ 29 in http_backoff                                                                               │
# │                                                                                                  │
# │   126 │   │   │   │   kwargs["data"].seek(io_obj_initial_pos)                                    │
# │   127 │   │   │                                                                                  │
# │   128 │   │   │   # Perform request and return if status_code is not in the retry list.          │
# │ ❱ 129 │   │   │   response = requests.request(method=method, url=url, **kwargs)                  │
# │   130 │   │   │   if response.status_code not in retry_on_status_codes:                          │
# │   131 │   │   │   │   return response                                                            │
# │   132                                                                                            │
# │                                                                                                  │
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\site-packages\requests\api.py:59 in request       │
# │                                                                                                  │
# │    56 │   # avoid leaving sockets open which can trigger a ResourceWarning in some               │
# │    57 │   # cases, and look like a memory leak in others.                                        │
# │    58 │   with sessions.Session() as session:                                                    │
# │ ❱  59 │   │   return session.request(method=method, url=url, **kwargs)                           │
# │    60                                                                                            │
# │    61                                                                                            │
# │    62 def get(url, params=None, **kwargs):                                                       │
# │                                                                                                  │
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\site-packages\requests\sessions.py:587 in request │
# │                                                                                                  │
# │   584 │   │   │   "allow_redirects": allow_redirects,                                            │
# │   585 │   │   }                                                                                  │
# │   586 │   │   send_kwargs.update(settings)                                                       │
# │ ❱ 587 │   │   resp = self.send(prep, **send_kwargs)                                              │
# │   588 │   │                                                                                      │
# │   589 │   │   return resp                                                                        │
# │   590                                                                                            │
# │                                                                                                  │
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\site-packages\requests\sessions.py:701 in send    │
# │                                                                                                  │
# │   698 │   │   start = preferred_clock()                                                          │
# │   699 │   │                                                                                      │
# │   700 │   │   # Send the request                                                                 │
# │ ❱ 701 │   │   r = adapter.send(request, **kwargs)                                                │
# │   702 │   │                                                                                      │
# │   703 │   │   # Total elapsed time of the request (approximately)                                │
# │   704 │   │   elapsed = preferred_clock() - start                                                │
# │                                                                                                  │
# │ C:\Users\A4023862\Anaconda3\envs\autogluon\lib\site-packages\requests\adapters.py:563 in send    │
# │                                                                                                  │
# │   560 │   │   │                                                                                  │
# │   561 │   │   │   if isinstance(e.reason, _SSLError):                                            │
# │   562 │   │   │   │   # This branch is for urllib3 v1.22 and later.                              │
# │ ❱ 563 │   │   │   │   raise SSLError(e, request=request)                                         │
# │   564 │   │   │                                                                                  │
# │   565 │   │   │   raise ConnectionError(e, request=request)                                      │
# │   566                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# SSLError: HTTPSConnectionPool(host='cdn-lfs.huggingface.co', port=443): Max retries exceeded with url:
# /google/electra-base-discriminator/ff381b988006468d184eb8c1c090be15553155daa960587e8d86465969f1a0c1?response-conten
# t-disposition=attachment%3B%20filename%3D%22pytorch_model.bin%22&Expires=1669895041&Policy=eyJTdGF0ZW1lbnQiOlt7IlJl
# c291cmNlIjoiaHR0cHM6Ly9jZG4tbGZzLmh1Z2dpbmdmYWNlLmNvL2dvb2dsZS9lbGVjdHJhLWJhc2UtZGlzY3JpbWluYXRvci9mZjM4MWI5ODgwMDY
# 0NjhkMTg0ZWI4YzFjMDkwYmUxNTU1MzE1NWRhYTk2MDU4N2U4ZDg2NDY1OTY5ZjFhMGMxP3Jlc3BvbnNlLWNvbnRlbnQtZGlzcG9zaXRpb249YXR0YW
# NobWVudCUzQiUyMGZpbGVuYW1lJTNEJTIycHl0b3JjaF9tb2RlbC5iaW4lMjIiLCJDb25kaXRpb24iOnsiRGF0ZUxlc3NUaGFuIjp7IkFXUzpFcG9ja
# FRpbWUiOjE2Njk4OTUwNDF9fX1dfQ__&Signature=ptbGGwmN-2yd3SxxLvBmrQNy0cIguya2BytPOENZG177zvP-pRKK0NHldihzZ~Q50cRFh9EGp
# 0lGhG1QzfDjLf3mwa-zrlA5ua~H2CLAEuL5H-hZC5iQTFlMC8R~svVMQuKs0go81o2Ir~0p6Zno752s2e5WFi9OqH0ybJGxycbRU8L644ADm~GAA8Lh
# aFO6M4CTYKmxF~syOgRmsir457JNb7ToqPJ-12nmA2HdmPAsaT0DNX5h-J7yGcZOCYsFkYVSWNj5q2X2ptytO65ScbASLXt8UmSmHv1izjif3CtRKAQ
# 8h6oW2jaPg~6ckDT72f5p9qtYQCLrMjuaGvDWiA__&Key-Pair-Id=KVTP0A1DKRTAX (Caused by SSLError(SSLCertVerificationError(1,
# '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate
# (_ssl.c:1129)')))
